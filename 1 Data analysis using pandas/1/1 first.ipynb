# %%
# What is Pandas?

# Pandas is an open-source Python library used for:

# Data manipulation

# Data cleaning

# Data analysis

# Data transformation

# Working with structured data (tables)

# It was created by Wes McKinney in 2008.

# It is built on top of:

# NumPy

# Python

# 🎯 Why Pandas is Important in Data Science

# In real-world data science:

# 70–80% time → Data cleaning

# 10–20% time → Modeling

# Pandas is mainly used in:

# Data preprocessing

# EDA (Exploratory Data Analysis)

# Feature engineering

# Preparing data for ML models

# %%
print("Working or not")
# Out:
# Working or not

# %%
import pandas as pd

# %%
# list 
data1=[1,2,3,4,5]
pd.DataFrame(data1)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data11=pd.DataFrame(data1)
print(data11)
type(data11)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
# pandas.DataFrame

# %%
data2=[["shan",23],["rihan",43]]
data22=pd.DataFrame(data2)
print(data22)
# Out:
#        0   1
# 0   shan  23
# 1  rihan  43

# %%
data22=pd.DataFrame(data2,columns=["name","age"])
print(data22)
# Out:
#     name  age
# 0   shan   23
# 1  rihan   43

# %%
data22=pd.DataFrame(data2,columns=("name","age"),index=[1,2])
print(data22)
# Out:
#     name  age
# 1   shan   23
# 2  rihan   43

# %%
# .

# %%
# use dictonery
data1={"name":["shan","rihan"],"age":[12,14]}

# %%
pd.DataFrame(data1)
# Out:
#     name  age
# 0   shan   12
# 1  rihan   14

# %%
newdata1=pd.DataFrame(data1)
print(newdata1)
# Out:
#     name  age
# 0   shan   12
# 1  rihan   14

# %%
# .

# %%
data2=[{"shan":12,"rihan":23},{"shan":23,"rihan":233,"faiz":90}]
data3=pd.DataFrame(data2)

# %%
data3["shan"].dtype
data3["shan"]
# Out:
# 0    12
# 1    23
# Name: shan, dtype: int64

# %%
# .

# %%
pd.read_csv("/home/choudhary/Desktop/LEARN with  GIT /DataScience-And-AI-Learning/1 Data analysis using pandas/csvdata1.csv")
# Out:
#             Name   class  gender  age
# 0  mohammad shan        2      m   23
# 1           rihan       3      m   44
# 2             nia       3      f   32
# 3             mir       2      f   23

# %%
pd.read_excel("/home/choudhary/Desktop/LEARN with  GIT /DataScience-And-AI-Learning/1 Data analysis using pandas/xldata1.xlsx")
# Out:
#             Name   class  gender  age
# 0  mohammad shan        2      m   23
# 1           rihan       3      m   44
# 2             nia       3      f   32
# 3             mir       2      f   23

# %%
pd.read_csv("/home/choudhary/Desktop/LEARN with  GIT /DataScience-And-AI-Learning/1 Data analysis using pandas/text.txt",sep="@")
# Out:
#             Name   class  gender  age
# 0  mohammad shan        2      m   23
# 1            riha       3      m   44
# 2              ni       3      f   32
# 3             mir       2      f   23

# %%
# .

# %%
data0 = {"name": ["rihan", "shan"], "age": 23}
print(type(data0))   # dict


df = pd.DataFrame(data0)
print(df)
# Out:
# <class 'dict'>
#     name  age
# 0  rihan   23
# 1   shan   23

# %%
import json

json_text = '{"name": ["rihan", "shan"], "age": 23}'
d = json.loads(json_text)

print(d)
print(type(d))   # dict
# Out:
# {'name': ['rihan', 'shan'], 'age': 23}
# <class 'dict'>

# %%
import json

json_text = '{"name": ["rihan", "shan"], "age": 23}'
d = json.loads(json_text)

print(d)
print(type(d))   # dict

# %%
# .

# %%
pd.read_csv("https://raw.githubusercontent.com/MohdShanChoudhary/DataScience-And-AI-Learning/refs/heads/main/1%20Data%20analysis%20using%20pandas/googleplaystore.csv")
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
shan=pd.read_csv("/home/choudhary/Desktop/LEARN with  GIT /DataScience-And-AI-Learning/1 Data analysis using pandas/csvdata1.csv")
print(shan)
print(shan.shape)
print("and")
print(shan.dtypes)
# Out:
#             Name   class  gender  age
# 0  mohammad shan        2      m   23
# 1           rihan       3      m   44
# 2             nia       3      f   32
# 3             mir       2      f   23
# (4, 4)
# and
# Name        str
# class     int64
# gender      str
# age       int64
# dtype: object

# %%
shan.head(2)
# Out:
#             Name   class  gender  age
# 0  mohammad shan        2      m   23
# 1           rihan       3      m   44

# %%
shan.tail(20)
# only  ending 5 rows will come
# Out:
#             Name   class  gender  age
# 0  mohammad shan        2      m   23
# 1           rihan       3      m   44
# 2             nia       3      f   32
# 3             mir       2      f   23

# %%
# for rendom sempal
shan.sample(4)
# Out:
#             Name   class  gender  age
# 2             nia       3      f   32
# 1           rihan       3      m   44
# 3             mir       2      f   23
# 0  mohammad shan        2      m   23

# %%
shan.values
# Out:
# array([['mohammad shan ', 2, 'm', 23],
#        ['rihan', 3, 'm', 44],
#        ['nia', 3, 'f', 32],
#        ['mir', 2, 'f', 23]], dtype=object)

# %%
shan.size
# Out:
# 16

# %%
shan.ndim
# Out:
# 2

# %%
shan.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1),
#  Index(['Name ', 'class ', 'gender', 'age'], dtype='str')]

# %%
shan.T
# transfrom
# Out:
#                      0      1    2    3
# Name    mohammad shan   rihan  nia  mir
# class                2      3    3    2
# gender               m      m    f    f
# age                 23     44   32   23

# %%
shan.empty
# Out:
# False

# %%
data={1,2,3,4,5}
n=pd.DataFrame(data)
print(n)
n.apply(lambda x:x+10)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
#     0
# 0  11
# 1  12
# 2  13
# 3  14
# 4  15

# %%
import numpy as np
n.apply(np.mean)
# Out:
# 0    3.0
# dtype: float64

# %%
n.reindex(index=["shan"])
# and rename is use for cloumn 
# df = df.rename(columns={
#     "name": "Name",
#     "age": "Age"
# })
# Out:
#        0
# shan NaN

# %%
# df.columns = ["Name", "Age"]   to change the name  of columns
# df.index = ["row1", "row2"]

# %%
print("test")
# Out:
# test

# %%
import pandas as pd 
df = pd.DataFrame({
    "A": [10, 20, 30],
    "B": [40, 50, 60]
}, index=["x", "y", "z"])

df.reindex(["z", "x", "y"])
print(df)
# Out:
#     A   B
# x  10  40
# y  20  50
# z  30  60

# %%
df = pd.DataFrame({
    "A": [10, 20, 30],
    "B": [40, 50, 60]
}, index=["x", "y", "z"])

df.reindex(["z", "x", "k","y"])
# Out:
#       A     B
# z  30.0  60.0
# x  10.0  40.0
# k   NaN   NaN
# y  20.0  50.0

# %%
df.reindex(["z", "x", "k","y"],fill_value="this is nan value ")
# Out:
#                     A                   B
# z                  30                  60
# x                  10                  40
# k  this is nan value   this is nan value
# y                  20                  50
